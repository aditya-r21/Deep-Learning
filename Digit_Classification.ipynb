# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-r21/Computer-Vision/blob/main/Digit_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

input_size = 28*28
hidden_size = 512
num_classes = 10
num_epochs = 3
batch_size = 100
learning_rate = 0.001

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

examples = iter(test_loader)
example_data, example_targets = next(examples)

class MLP(nn.Module):
  def __init__(self, input_size, hidden_size, num_classes):
    super(MLP, self).__init__()
    self.input_size = input_size
    self.l1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.LeakyReLU()
    self.l2 = nn.Linear(hidden_size, num_classes)

  def forward(self, x):
    out = self.l1(x)
    out = self.relu(out)
    out = self.l2(out)
    return out

model = MLP(input_size, hidden_size, num_classes)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

n_total_steps = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')

    # why is loss not always decreasing?
# Out:
# Epoch [1/3], Step [100/600], Loss: 0.3697
# Epoch [1/3], Step [200/600], Loss: 0.2711
# Epoch [1/3], Step [300/600], Loss: 0.3477
# Epoch [1/3], Step [400/600], Loss: 0.2742
# Epoch [1/3], Step [500/600], Loss: 0.1093
# Epoch [1/3], Step [600/600], Loss: 0.1701
# Epoch [2/3], Step [100/600], Loss: 0.1121
# Epoch [2/3], Step [200/600], Loss: 0.0813
# Epoch [2/3], Step [300/600], Loss: 0.0356
# Epoch [2/3], Step [400/600], Loss: 0.0379
# Epoch [2/3], Step [500/600], Loss: 0.1032
# Epoch [2/3], Step [600/600], Loss: 0.1332
# Epoch [3/3], Step [100/600], Loss: 0.0562
# Epoch [3/3], Step [200/600], Loss: 0.0505
# Epoch [3/3], Step [300/600], Loss: 0.0582
# Epoch [3/3], Step [400/600], Loss: 0.0315
# Epoch [3/3], Step [500/600], Loss: 0.0778
# Epoch [3/3], Step [600/600], Loss: 0.0635
# Accuracy of the network on the 10000 test images: 97.21 %

# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

input_size = 28*28
hidden_size = 512
num_classes = 10
num_epochs = 3
batch_size = 100
learning_rate = 0.001

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

examples = iter(test_loader)
example_data, example_targets = next(examples)

class MLP(nn.Module):
  def __init__(self, input_size, hidden_size, num_classes):
    super(MLP, self).__init__()
    self.input_size = input_size
    self.l1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.LeakyReLU()
    self.l2 = nn.Linear(hidden_size, num_classes)

  def forward(self, x):
    out = self.l1(x)
    out = self.relu(out)
    out = self.l2(out)
    return out

model = MLP(input_size, hidden_size, num_classes)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr = learning_rate)

n_total_steps = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Epoch [1/3], Step [100/600], Loss: 0.4080
# Epoch [1/3], Step [200/600], Loss: 0.2023
# Epoch [1/3], Step [300/600], Loss: 0.3383
# Epoch [1/3], Step [400/600], Loss: 0.2158
# Epoch [1/3], Step [500/600], Loss: 0.1393
# Epoch [1/3], Step [600/600], Loss: 0.1821
# Epoch [2/3], Step [100/600], Loss: 0.1143
# Epoch [2/3], Step [200/600], Loss: 0.0686
# Epoch [2/3], Step [300/600], Loss: 0.0413
# Epoch [2/3], Step [400/600], Loss: 0.0919
# Epoch [2/3], Step [500/600], Loss: 0.0793
# Epoch [2/3], Step [600/600], Loss: 0.1300
# Epoch [3/3], Step [100/600], Loss: 0.0929
# Epoch [3/3], Step [200/600], Loss: 0.0711
# Epoch [3/3], Step [300/600], Loss: 0.0270
# Epoch [3/3], Step [400/600], Loss: 0.1203
# Epoch [3/3], Step [500/600], Loss: 0.0508
# Epoch [3/3], Step [600/600], Loss: 0.0517
# Accuracy of the network on the 10000 test images: 97.63 %

# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

input_size = 28*28
hidden_size = 512
num_classes = 10
num_epochs = 3
batch_size = 100
learning_rate = 0.01

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

examples = iter(test_loader)
example_data, example_targets = next(examples)

class MLP(nn.Module):
  def __init__(self, input_size, hidden_size, num_classes):
    super(MLP, self).__init__()
    self.input_size = input_size
    self.l1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.LeakyReLU()
    self.l2 = nn.Linear(hidden_size, num_classes)

  def forward(self, x):
    out = self.l1(x)
    out = self.relu(out)
    out = self.l2(out)
    return out

model = MLP(input_size, hidden_size, num_classes)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

n_total_steps = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Epoch [1/3], Step [100/600], Loss: 2.0977
# Epoch [1/3], Step [200/600], Loss: 1.7150
# Epoch [1/3], Step [300/600], Loss: 1.4127
# Epoch [1/3], Step [400/600], Loss: 1.1087
# Epoch [1/3], Step [500/600], Loss: 0.8791
# Epoch [1/3], Step [600/600], Loss: 0.8526
# Epoch [2/3], Step [100/600], Loss: 0.7158
# Epoch [2/3], Step [200/600], Loss: 0.6487
# Epoch [2/3], Step [300/600], Loss: 0.6457
# Epoch [2/3], Step [400/600], Loss: 0.5203
# Epoch [2/3], Step [500/600], Loss: 0.4447
# Epoch [2/3], Step [600/600], Loss: 0.4877
# Epoch [3/3], Step [100/600], Loss: 0.4984
# Epoch [3/3], Step [200/600], Loss: 0.4039
# Epoch [3/3], Step [300/600], Loss: 0.4241
# Epoch [3/3], Step [400/600], Loss: 0.5181
# Epoch [3/3], Step [500/600], Loss: 0.4417
# Epoch [3/3], Step [600/600], Loss: 0.4016
# Accuracy of the network on the 10000 test images: 89.36 %

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

num_epochs = 3
batch_size = 100
learning_rate = 0.01

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

examples = iter(test_loader)
example_data, example_targets = next(examples)

class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(1, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 4 * 4, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 16 * 4 * 4)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x


model = CNN()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

n_total_steps = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Epoch [1/3], Step [100/600], Loss: 0.3593
# Epoch [1/3], Step [200/600], Loss: 0.1211
# Epoch [1/3], Step [300/600], Loss: 0.1663
# Epoch [1/3], Step [400/600], Loss: 0.1084
# Epoch [1/3], Step [500/600], Loss: 0.0153
# Epoch [1/3], Step [600/600], Loss: 0.0654
# Epoch [2/3], Step [100/600], Loss: 0.0964
# Epoch [2/3], Step [200/600], Loss: 0.0311
# Epoch [2/3], Step [300/600], Loss: 0.0173
# Epoch [2/3], Step [400/600], Loss: 0.0676
# Epoch [2/3], Step [500/600], Loss: 0.0895
# Epoch [2/3], Step [600/600], Loss: 0.0517
# Epoch [3/3], Step [100/600], Loss: 0.0153
# Epoch [3/3], Step [200/600], Loss: 0.0608
# Epoch [3/3], Step [300/600], Loss: 0.0085
# Epoch [3/3], Step [400/600], Loss: 0.0789
# Epoch [3/3], Step [500/600], Loss: 0.0139
# Epoch [3/3], Step [600/600], Loss: 0.0369
# Accuracy of the network on the 10000 test images: 98.19 %

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

num_epochs = 3
batch_size = 100
learning_rate = 0.001

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

examples = iter(test_loader)
example_data, example_targets = next(examples)

class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(1, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 4 * 4, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 16 * 4 * 4)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x


model = CNN()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr = learning_rate)

n_total_steps = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Epoch [1/3], Step [100/600], Loss: 0.5221
# Epoch [1/3], Step [200/600], Loss: 0.2607
# Epoch [1/3], Step [300/600], Loss: 0.2405
# Epoch [1/3], Step [400/600], Loss: 0.2607
# Epoch [1/3], Step [500/600], Loss: 0.1937
# Epoch [1/3], Step [600/600], Loss: 0.1879
# Epoch [2/3], Step [100/600], Loss: 0.1041
# Epoch [2/3], Step [200/600], Loss: 0.0858
# Epoch [2/3], Step [300/600], Loss: 0.1438
# Epoch [2/3], Step [400/600], Loss: 0.0606
# Epoch [2/3], Step [500/600], Loss: 0.0720
# Epoch [2/3], Step [600/600], Loss: 0.1364
# Epoch [3/3], Step [100/600], Loss: 0.0450
# Epoch [3/3], Step [200/600], Loss: 0.0878
# Epoch [3/3], Step [300/600], Loss: 0.0587
# Epoch [3/3], Step [400/600], Loss: 0.0398
# Epoch [3/3], Step [500/600], Loss: 0.1152
# Epoch [3/3], Step [600/600], Loss: 0.0523
# Accuracy of the network on the 10000 test images: 98.13 %

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

num_epochs = 3
batch_size = 100
learning_rate = 0.01

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(),  download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

examples = iter(test_loader)
example_data, example_targets = next(examples)

class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(1, 6, 5)
    self.pool = nn.MaxPool2d(2, 2)
    self.conv2 = nn.Conv2d(6, 16, 5)
    self.fc1 = nn.Linear(16 * 4 * 4, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, 10)

  def forward(self, x):
    x = self.pool(F.relu(self.conv1(x)))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 16 * 4 * 4)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x


model = CNN()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

n_total_steps = len(train_loader)

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Epoch [1/3], Step [100/600], Loss: 2.3032
# Epoch [1/3], Step [200/600], Loss: 2.3012
# Epoch [1/3], Step [300/600], Loss: 2.2930
# Epoch [1/3], Step [400/600], Loss: 2.2857
# Epoch [1/3], Step [500/600], Loss: 2.2916
# Epoch [1/3], Step [600/600], Loss: 2.2938
# Epoch [2/3], Step [100/600], Loss: 2.2883
# Epoch [2/3], Step [200/600], Loss: 2.2912
# Epoch [2/3], Step [300/600], Loss: 2.2845
# Epoch [2/3], Step [400/600], Loss: 2.2730
# Epoch [2/3], Step [500/600], Loss: 2.2650
# Epoch [2/3], Step [600/600], Loss: 2.2190
# Epoch [3/3], Step [100/600], Loss: 2.1336
# Epoch [3/3], Step [200/600], Loss: 1.8831
# Epoch [3/3], Step [300/600], Loss: 1.3309
# Epoch [3/3], Step [400/600], Loss: 0.9463
# Epoch [3/3], Step [500/600], Loss: 0.5561
# Epoch [3/3], Step [600/600], Loss: 0.3809
# Accuracy of the network on the 10000 test images: 84.33 %
